# %% [markdown]
# <a href="https://colab.research.google.com/github/Radmir27/BaaS/blob/main/Abkarimov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Тема: Высокопроизводительная аналитика на суперкомпьютере,
# Абкаримов Радмир Маратович,
# ПИ-321

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
reg = linear_model.LinearRegression()
np.random.seed(19130598)
A = []
B = []
T = []
N = 10000
n = 1000

# %%
for i in range(n):
  t = time.time()
  x = np.random.uniform(low=150, high=200, size=N)
  e = np.random.normal(loc=0, scale=10, size=N)
  y = -100 + x + e
  reg.fit(x.reshape(-1, 1), y.reshape(-1, 1))
  A.append(reg.intercept_[0])
  B.append(reg.coef_[0][0])
  T.append(time.time() - t)

# %%
plt.figure(figsize=(10, 6))
plt.hist(B, bins = 20, edgecolor='black', color='white')
plt.title('Histogram of B estimates')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(A, bins = 20, edgecolor='black', color='white')
plt.title('Histogram of A estimates')
plt.show()

# %%
min(T), np.median(T), max(T)
# Out:
# (0.0011150836944580078, 0.0011497735977172852, 0.08349847793579102)

# %%
plt.figure(figsize=(10, 4))
plt.plot(T, marker='.')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(T[100:200], marker='.')
plt.show()

# %%
# Изменен диапазон
plt.figure(figsize=(10, 4))
plt.plot(T[500:1000], marker='.')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.hist(T[500:1000], bins = 30, edgecolor='black', color='white')
plt.show()
