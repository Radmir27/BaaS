# %% [markdown]
# <p align="center"><b>Греческий алфавит</b></p>
#
# | Заглавная | Строчная | Название |
# | --- | --- | --- |
# | Α | α | альфа |
# | Β | β | бета (вита) |
# | Γ | γ | гамма |
# | Δ | δ | дельта |
# | Ε | ϵ | эпсилон |
# | Ζ | ζ | дзета  (зита) |
# | Η | η | эта (ита) |
# | Θ | θ | тета (фита) |
# | Ι | ι | йота |
# | Κ | κ | каппа |
# | Λ | λ | лямбда (лямда) |
# | M | μ | мю (ми) |
# | N | ν | ню (ни) |
# | Ξ | ξ | кси |
# | O | o | омикрон |
# | Π | π | пи |
# | Ρ | ρ | ро |
# | Σ | σ | сигма |
# | Τ | τ | тау (тав) |
# | Υ | υ | ипсилон |
# | Φ | ϕ | фи |
# | Χ | χ | хи |
# | Ψ | ψ | пси |
# | Ω | ω | омега |
#
# Формула для нормального распределения в LaTeX будет выглядеть так:
#
#  $${f(x) = {\frac {1}{\sigma {\sqrt {2\pi }}}} e^ {-{\frac {1}{2}} \left({\frac {x-μ }{σ }}\right)^{2}}}$$
